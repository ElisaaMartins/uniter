# %% [markdown]
# <a href="https://colab.research.google.com/github/ElisaaMartins/uniter/blob/main/logicaProgamacaoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Python Uninter | Lógica**

# %% [markdown]
# **Função de print na tela**

# %%
print('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# **Sintaxe**

# %%
Print ('Olá, mundo!') - vai dar erro de sintaxe

# %% [markdown]
# **Funções**

# %%
print(2 + 3)
# Out:
# 5

# %%
print('2 + 3')
# Out:
# 2 + 3

# %% [markdown]
# **Concatenação de textos**

# %%
print('2' + '3')
# Out:
# 23

# %% [markdown]
# **Operadores e operações matemáticas**

# %%
print(10*(5+7)/4)
# Out:
# 30.0

# %%
print(10*(5+7/4))
# Out:
# 67.5

# %% [markdown]
# **Variáveis, dados e seus tipos**

# %%
nota = 8.5
disciplina = 'Lógica de proggramação e algortimos'

print(nota)
print(disciplina)
# Out:
# 8.5
# Lógica de proggramação e algortimos

# %%
print('Disciplina:', disciplina, '- Nota:', nota)
# Out:
# Disciplina: Lógica de proggramação e algortimos - Nota: 8.5

# %% [markdown]
# Variável lógica

# %%
a = 1
b = 5

resposta = a == b
print(resposta)
# Out:
# False

# %%
resposta = a != b
print(resposta)
# Out:
# True

# %% [markdown]
# Variavél string

# %%
frase = 'Olá, mundo!'
print(frase)
# Out:
# Olá, mundo!

# %% [markdown]
# Acessando o índice (caractere individual)

# %%
print(frase[0])
print(frase[2])
# Out:
# O
# á

# %% [markdown]
# **Manipulação de strings**

# %% [markdown]
# Concatenação

# %%
s1 = 'Lógica de programação'
s1 = s1 + 'e algoritmos'
print(s1)
# Out:
# Lógica de programaçãoe algoritmos

# %% [markdown]
# Repetindo strings na concatenação

# %%
s1 = 'A' + '-' * 10 + 'B'
print(s1)

s1 = 'A' + ' ' * 10 + 'B'
print(s1)
# Out:
# A----------B
# A          B

# %% [markdown]
# Composição com marcadores de posição

# %%
nota = 8.5
s1 = 'Você tirou %f na disciplina de algoritmos' % nota
print(s1)
# Out:
# Você tirou 8.500000 na disciplina de algoritmos

# %% [markdown]
# Limitando as casas decimais

# %%
nota = 8.5
s1 = 'Você tirou %.2f na disciplina de algoritmos' % nota
print(s1)
# Out:
# Você tirou 8.50 na disciplina de algoritmos

# %% [markdown]
# Várias variáveis

# %%
nota = 8.5
disciplina = 'algoritmos'
s1 = 'Você tirou %.2f na disciplina de %s' % (nota, disciplina)
print(s1)
# Out:
# Você tirou 8.50 na disciplina de algoritmos

# %% [markdown]
# Composição moderena

# %%
nota = 8.5
disciplina = 'algoritmos'
s1 = 'Você tirou {} na disciplina de {}'.format(nota, disciplina)
print(s1)
# Out:
# Você tirou 8.5 na disciplina de algoritmos

# %% [markdown]
# Composição com f-string

# %%
nota = 8.5
disciplina = 'algoritmos'
s1 = f'Você tirou {nota} na disciplina de {disciplina}'
print(s1)
# Out:
# Você tirou 8.5 na disciplina de algoritmos

# %% [markdown]
# Fatiamento de strings | pedaços

# %%
s1 ='Lógica de Programação e algoritmos'
print(s1[0:6]) # sempre um numero a mais

print(s1[24:34])

print(s1[24:])
print(s1[:6])
# Out:
# Lógica
# algoritmos
# Lógica

# %% [markdown]
# Lenght | Tamanho

# %%
s1 ='Lógica de Programação e algoritmos'
tamanho = len(s1)
print(tamanho)
# Out:
# 34

# %% [markdown]
# **Comando de entrada**

# %% [markdown]
# INPUT

# %%
idade = input('Idade: ')
print(idade)
# Out:
# Idade: 21
# 21

# %%
nome = input('Nome: ')
print(f'Olá {nome}, seja bem-vindo"')
# Out:
# Nome: elisa
# Olá elisa, seja bem-vindo"

# %% [markdown]
# Convertendo dados de entrada (casting)

# %%
nota = float(input('Nota: '))
print(f'Você tirou a nota: {nota}')
# Out:
# Nota: 1.5
# Você tirou a nota: 1.5

# %% [markdown]
# **Fluco de execução do programa | Teste de mesa**

# %%
x = 1
y = 1
z = x + y # z = 1 + 1 = 2

x = x + 2 # x = 2 + 3 = 3
y = y - 1 # y = 1 - 1 = 0
z = x + y # z = 3 + 0 = 3

x = y + 1 # x = 0 + 1 = 1
y = x - 1 # y = 1 - 1 = 0
z = x + y # z = 1 + 0 = 1

print(z)
# Out:
# 1

# %% [markdown]
# **Exercicío**

# %%
1.Desenvolva um algoritmo que solicite ao usuário dois números inteiros.
  Imprima a soma desses dois números na tela

# %%
n1 = int(input('Numero Inteiro 1: '))
n2 = int(input('Numero Inteiro 2: '))

soma = n1 + n2

print(f'Soma {n1} + {n2} = {soma}')
# Out:
# Numero Inteiro 1: 10
# Numero Inteiro 2: 10
# Soma 10 + 10 = 20

# %% [markdown]
# **Condições**

# %% [markdown]
# Condicional Simples

# %% [markdown]
# 1. Desenvolva um programa que leia dois primeiro é maior do que o segundo,valores numéricos inteiros e compare se o utilizando uma condicional simples. Caso seja (resultado verdadeiro), ele imprime na tela a mensagem informando que o primeiro valor digitado é maior do que o segundo.

# %%
# Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))

if (x > y):
  print('O primeiro valor é maior que o segundo! ') # se for ao contrario não imprime nada
# Out:
# Digite um valor inteiro: 15
# Digite um segundo valor inteiro: 10
# O primeiro valor é maior que o segundo!

# %%
# Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))

if (x > y):
  print('O primeiro valor é maior que o segundo!')
if (x < y):
  print('O segundo valor é maior que o segundo! ')
# Out:
# Digite um valor inteiro: 10
# Digite um segundo valor inteiro: 15
# O segundo valor é maior que o segundo!

# %% [markdown]
# Condicional Composta

# %%
# Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))

if (x > y):
  print('O primeiro valor é maior que o segundo! ')
else:
  print('O segundo valor é maior que o segundo! ')
# Out:
# Digite um valor inteiro: 10
# Digite um segundo valor inteiro: 10
# O segundo valor é maior que o segundo!

# %% [markdown]
# 1. Desenvolva um programa que leia um valor, inteiro e descubra se ele é par ou ímpar

# %%
# par ou ímpar
x = int(input('Digite um valor inteiro: '))
if (x % 2 == 0):
  print('O número é par! ')
else:
  print('O número é ímpar! ')
# Out:
# Digite um valor inteiro: 1
# O número é ímpar!

# %% [markdown]
# **Operadores lógicos e booleanos**

# %%
# not
x = True
y = False
print(not x)
print(not y)
# Out:
# False
# True

# %%
# and
x = False # se aqui True seria True
y = True
print(x and y)
# Out:
# False

# %%
# or
x = False
y = True
print(x or y)
# Out:
# True

# %%
x = 10
y = 1
z = 5.5
res = (x > y) and (z == y) # True and False
print(res)
# Out:
# False

# %%
x = 10
y = 1
res = not (x > y) # primeiro o operador de maior/menor
print(res)
# Out:
# False

# %%
x = 10
y = 1
Z = 5.5
res = (x > y) or (not z == y) and (y != y + (z / x)) #1.55

# res = True or not False and True
# res = True or True and True
# res = True or True

print(res)
# Out:
# True

# %% [markdown]
# **Exercicíos**

# %% [markdown]
# 1. Um aluno, para passar de ano, precisa ser aprovado em todas as matérias que está cursando. Assuma que a média para **aprovação é a partir de 7** e que o **aluno cursa 3 matérias**, somente. Escreva um algoritmo que leia a nota final do aluno em cada matéria e informe, na tela, se ele passou de ano ou não.

# %%
m1 = float(input('Digite a nota da 1ª matéria: ' ))
m2 = float(input('Digite a nota da 2ª matéria: ' ))
m3 = float(input('Digite a nota da 3ª matéria: ' ))

if m1 >=7 and m2 >=7 and m3 >= 7:
  print('O aluno está aprovado de ano! ');
else:
  print('O aluno não passou de ano! ');
# Out:
# Digite a nota da 1ª matéria: 10
# Digite a nota da 2ª matéria: 4
# Digite a nota da 3ª matéria: 3
# O aluno não passou de ano!

# %% [markdown]
# 2. Escreva um algoritmo em Python em que o usuário escolhe se quer comprar maçãs, laranjas ou bananas. Deverá ser apresentado na tela um menu com as opções:
#     * 1 - maçã,
#     * 2 - laranja
#     * 3 - banana
#
#     Após escolhida a fruta, deve-se digitar quantas unidades se quer comprar. O algoritmo deve calcular o preço total a pagar do produto escolhido e mostrá-lo na tela. Considere que:
#     * maçã - 2,30
#     * laranja - 3,60
#     * banana - 1,85

# %%
print('Escolha o que deseja comprar: ' )
print('1 - Maça')
print('2 - Laranja')
print('3 - Banana')

produto = int(input('Qual sua escolha?'))
qtd = int(input('Quantas unidades?'))

if (produto == 1):
  pagar = qtd * 2.3
  print(f'Você comprou {qtd} maças. Total à pagar: {pagar}' )
else:
  if (produto == 2):
    pagar = qtd * 3.6
    print(f'Você comprou {qtd} laranjas. Total a pagar: {pagar}' )
  else:
    if (produto == 3):
      pagar = qtd * 1.85
      print(f'Você comprou {qtd} bananas. Total a pagar: {pagar}' )
    else:
      print('Produto inexistente!')
# Out:
# Escolha o que deseja comprar:
# 1 - Maça
# 2 .- Laranja
# 3 - Banana
# Qual sua escolha?1
# Quantas unidades?2
# Você comprou 2 maças. Total à pagar: 4.6

# %% [markdown]
# Usando o **elif**

# %%
print('Escolha o que deseja comprar: ' )
print('1 - Maça')
print('2 - Laranja')
print('3 - Banana')

produto = int(input('Qual sua escolha?'))
qtd = int(input('Quantas unidades?'))

if (produto == 1):
  pagar = qtd * 2.3
  print(f'Você comprou {qtd} maças. Total à pagar: {pagar}' )
elif (produto == 2):
  pagar = qtd * 3.6
  print(f'Você comprou {qtd} laranjas. Total a pagar: {pagar}' )
elif (produto == 3):
  pagar = qtd * 1.85
  print(f'Você comprou {qtd} bananas. Total a pagar: {pagar}' )
else:
  print('Produto inexistente!')

# %% [markdown]
# 3. Escreva um algoritmo que leia um nome e uma idade:
#   * Caso o nome digitado seja Vinicius, escreva isso na tela;
#   * Caso o usuário digite qualquer outro nome, verifique sua idade. Se for menor que 18 anos, informe que é de menor. Se for maior que 100 anos, informe que esta pessoa possivelmente não existe;

# %%
nome = input ('Qual seu nome? ')
idade = int(input('Qual sua idade? '))

if nome == 'Vinicius' :
  print('Olá, Vinicius!')
elif idade < 18:
  print('Você não é o Vinicius! E é menor de idade! ')
elif idade > 100:
  print('Diferente de você, o Vinicius não é imortal! ')
# Out:
# Qual seu nome?elisa
# Qual sua idade?16
# Você não é o Vinicius! E é menor de idade!

# %% [markdown]
# **Estruturas de repetição**

# %%
x = 1
print(x)
x = x + 1
print(x)
x = x + 1
print(x)
x = x + 1
print(x)
x = x + 1
print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **While (enquanto)**

# %%
x = 1
while (x <= 5):
  print(x)
  x = x + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Loop infinito

# %%
x = 1
while (x <= 5):
  print(x)
  # x = x + 1

# %% [markdown]
# Variável de controle

# %%
x = 0
while (x < 100):
  print(x)
  x = x + 1

# %%
x = 0
while (x <= 99) :
  print(x)
  x = x + 1

# %% [markdown]
# Contadores

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1. Escreva um algoritmo que imprima na tela somente valores dentro de um intervalo especificado pelo usuário e que sejam número pares

# %%
inicial = int(input('Qual valor deseja iniciar a contagem?'))
final = int(input('Qual valor deseja encerrar a contagem?'))

x = inicial

while (x <= final):
  #Verifica se o número é par
  if (x % 2 == 0):
    print(x)
  x = x + 1

# %% [markdown]
# Acumuladores

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1. Escreva um algoritmo que calcule a sua média de notas em determinada disciplina. Vamos assumir que a média final é dada pela média aritmética de cinco notas digitadas

# %%
soma = 0
cont = 1

while (cont <= 5):
  x = float(input(f'Digite a {cont} nota:'))
  soma = soma + x
  cont = cont + 1

media = soma / 5
print(f'Média final: {media}')

# %% [markdown]
# Tópicos importantes de laços em Python

# %% [markdown]
# Operadores especiais de atribuição

# %%
soma = 0
cont = 1

while (cont <= 5):
  x = int(input(f'Digite o (cont) número:'))
  soma += x # Equivalente: soma soma + x
  cont += 1 # Equivalente: cont cont + 1
print(f'Somatório: {soma}')

# %% [markdown]
# Validando dados de entrada

# %% [markdown]
# **Exemplo**
#
# Crie um algoritmo que receba um valor do tipo inteiro via teclado. No entanto, o programa só deve aceitar, obrigatoriamente, valores inteiros e positivos. Qualquer valor negativo, ou igual a zero, deve ser rejeitado pelo programa e um novo valor deve ser solicitado

# %%
# Validando a entrada
x = int(input('Digite um valor maior do que zero:'))

while (x <= 0):
  x = int(input('Digite um valor maior do que zero: '))
print(f'Você digitou (x). Encerrando o programa...')

# %% [markdown]
# **Instrução BREAK**

# %% [markdown]
# Escreva um algoritmo que fique recebendo frases ou palavras digitadas pelo usuário. Encerre o algoritmo quando a palavra "sair" for digitada

# %%
print('Digite uma mensagem que irei repetir para você!')
print('Para encerrar escreva "sair".')

while True:
  texto = input('')
  print(texto)
  if texto == 'sair':
    break

print('Encerrando o programa...')
# Out:
# Digite uma mensagem que irei repetir para você!
# Para encerrar escreva "sair".
# queijo]
# queijo]
# sair
# sair
# Encerrando o programa...

# %% [markdown]
# **Instrução CONTINUE**

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1. Escreva um algoritmo que realize um login em um sistema. O usuário deve informar seu nome e senha
#
#     Sistema de "Login e Senha"

# %%
while True:
  nome = input('Qual o seu nome?')
  if (nome != 'Lenhadorzinho'):
    continue # volta para inicio do laço
  senha = input('Qual a sua senha?')
  if (senha == 'UnInTeR'):
    break # encerra o laço
print('Acesso concedido.')
# Out:
# Qual o seu nome?elisa
# Qual o seu nome?Lenhadorzinho
# Qual a sua senha?lapis
# Qual o seu nome?Lenhadorzinho
# Qual a sua senha?UnInTeR
# Acesso concedido.

# %% [markdown]
# Valores Truthy e Falsey

# %%
nome = '' # Falsey
while not nome: # Not falsey (Truthy)
  # encerra o laço quando nome não estiver vazio nome = input('Digite seu nome:')
  nome = input('Digite seu nome: ')

valor = int(input('Digite um número qualquer:'))
if valor: #Equivalente if valor != 0
  print('Você digitou um valor diferente de zero.')
else:
  print('Você digitou zero.')
# Out:
# Digite seu nome: Elisa
# Digite um número qualquer:10
# Você digitou um valor diferente de zero.

# %% [markdown]
# **For (para)**

# %%
for i in range(6): # 6 valor final (-1)
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6,1):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(10,0,-2): # diminui de dois em dois
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %% [markdown]
# Varredura de strings

# %%
frase = 'Lógica de Programação e Algoritmos'

for i in range(0, len(frase), 1):
  print(frase[i], end="") # para imprimir tudo em uma linha
# Out:
# Lógica de Programação e Algoritmos

# %% [markdown]
# **Exercícios**

# %% [markdown]
# 1. Escreva um algoritmo que calcule a média dos números pares de 1 até 100 (1 e 100 inclusos). Implemente o laço usando for

# %%
soma = 0
qtd = 0

for i in range (1, 101):
  if (i % 2 == 0):
    soma += i
    qtd += 1

media = soma / qtd
print (f'A média dos pares de 0 até 100 é: {media}')
# Out:
# A média dos pares de 0 até 100 é: 51.0

# %% [markdown]
# **Estruturas de repetição aninhadas**

# %% [markdown]
# **Exercícios**

# %% [markdown]
# 1. Escreva um algoritmo em Python que calcule a tabuada de todos os números de 1 até 10, e, para cada número, vamos calcular a tabuada multiplicando-o pelo intervalo de 1 até 10

# %% [markdown]
# 2x While

# %%
tabuada= 1
while tabuada <= 10:
  print(f'TABUADA DO (tabuada):')
  i = 1
  while i <= 10:
    print(f'{tabuada} x {i} = {tabuada * i}')
    i += 1
  tabuada += 1
# Out:
# TABUADA DO (tabuada):
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# TABUADA DO (tabuada):
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# TABUADA DO (tabuada):
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# TABUADA DO (tabuada):
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# TABUADA DO (tabuada):
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# TABUADA DO (tabuada):
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# TABUADA DO (tabuada):
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# ...

# %% [markdown]
# 2x For

# %%
for tabuada in range(1, 11, 1):
  print(f'TABUADA DO {tabuada}:')
  for i in range(1, 11, 1):
    print(f'{tabuada} x {i} = {tabuada * i}')
# Out:
# TABUADA DO 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# TABUADA DO 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# TABUADA DO 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# TABUADA DO 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# TABUADA DO 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# TABUADA DO 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# TABUADA DO 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# ...

# %% [markdown]
# 1x While e 1x For

# %%
tabuada = 1
while tabuada <= 10:
  print (f'TABUADA DO {tabuada}:')
  for i in range(1, 11, 1):
    print (f'{tabuada} x {i} = {tabuada * i}')
  tabuada += 1
# Out:
# TABUADA DO 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# TABUADA DO 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# TABUADA DO 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# TABUADA DO 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# TABUADA DO 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# TABUADA DO 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# TABUADA DO 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# ...

# %% [markdown]
# **Funções**

# %%
print('|','_' * 10, '|')
print('|','_' * 10, '|')
print('     MENU')
print('|','_' * 10, '|')
print('|','_' * 10, '|')
# Out:
# | __________ |
# | __________ |
#      MENU
# | __________ |
# | __________ |

# %% [markdown]
# O mesmo código só que com uma função

# %%
def realce():
  #corpo da função
  print('|','_' * 10, '|')
  print('|','_' * 10, '|')

#Programa principal
realce()
print('     MENU')
realce()
# Out:
# | __________ |
# | __________ |
#      MENU
# | __________ |
# | __________ |

# %% [markdown]
# **Parâmentros e passagem de parâmetros**

# %%
def realce(s1):
  print('|','_' * 10, '|')
  print('|','_' * 10, '|')
  print(s1)
  print('|','_' * 10, '|')
  print('|','_' * 10, '|')

# programa principal
realce('     MENU')
# Out:
# | __________ |
# | __________ |
#      MENU
# | __________ |
# | __________ |

# %%
def sub2(x, y):
  res = x
  print(res)

# Programa principal
sub2(5, 7)
sub2(7, 5)
sub2 ( y = 7 , x = 5 )
# Out:
# 5
# 7
# 5

# %% [markdown]
# Parâmetros opicionais

# %%
def soma3(x, y, z):
  res = x + y + z
  print(res)

def soma3( x = 0 , y = 0, z = 0):
  res = x + y + z
  print(res)

soma3 (1,2,3)
soma3(1,2)    #z foi omitido
soma3 (1)     #y e z foram omitidos
soma3()       #x, y e z foram omitidos
# Out:
# 6
# 3
# 1
# 0

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1. Escreva uma rotina que crie uma borda ao redor de uma palavra, para desstacá-la como sendo um título. A rotina deve receber como parâmetro a palavra a ser destacada. O tamanho da caixa de texto deverá ser adaptável, de acordo com o tamanho da palavra

# %%
def borda(s1):
  tam = len(s1)
  # só imprime caso exista algum caractere

  if tam:
    print('+','-' * tam,'+')
    print('|', s1,'|')
    print('+','-' * tam, '+')

#Programa Principal
borda('Olá, Mundo!')
borda('Lógica de Programação e Algoritmos')
# Out:
# + ----------- +
# | Olá, Mundo! |
# + ----------- +
# + ---------------------------------- +
# | Lógica de Programação e Algoritmos |
# + ---------------------------------- +

# %% [markdown]
# **Escopo de váriaveis**

# %%
def omelete():
  ovos = 12 # variável local

#Programa principal
omelete()
print(ovos) # escopo global

# %%
def omelete():
  print(ovos) # escopo local

#Programa principal
ovos = 12 # variável global
omelete()

# %%
def omelete():
  ovos = 12
  bacon()
  print(ovos)

def bacon():
  ovos = 6

#Programa principal
omelete()

# %%
def omelete():
  ovos = 12 #'variável local de omelete'
  print('Ovos = ', ovos)

def bacon():
  ovos = 6  #'variável local de bacon'
  print('Ovos = ', ovos)
  omelete()
  print('Ovos = ', ovos)

#Programa principal
ovos = 2  #'variável global'
bacon()
print('Ovos = ', ovos)

# %% [markdown]
# Instrução global

# %%
def omelete():
  global ovos
  ovos = 6

#Programa principal
ovos = 12
omelete()
print(ovos)

# %%
def omelete():
  global ovos
  ovos = 6
  bacon()

def bacon():
  ovos = 12
  pimenta()

def pimenta():
  print(ovos)

#Programa principal
ovos = 4
omelete()
print(ovos)

# %%
def omelete():
  print(ovos)
  ovos = 6
  ovos = 12

omelete()

# %% [markdown]
# **Retorno de valores em função**

# %%
def soma3 ( x = 0 , y = 0, z = 0 ) :
  res = x + y + z
  return res

# Programa principal
retornado = soma3 (1,2,3)
print(retornado)

# forma alternativa simplificada
print(soma3 (2,2))

# %%
# Programa principal
retornado1 = soma3 (1,2,3)
retornado2 = soma3(1,2)
retornado3 = soma3()
print(f'Somatórios: {retornado1}, {retornado2} e {retornado3}.')

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1.Escreva uma função para validar uma string.
# Essa função recebe como parâmetro a string, o número mínimo e máximo de caracteres. Retorne verdadeiro se o tamanho da string estiver entre os valores de mínimo e máximo, e falso, caso contrário (elaborado com base em Menezes, s. d.)

# %%
# Exercicio 1
def valida_string(pergunta, min, max):
  s1= input(pergunta)
  tam = len(s1)
  while((tam < min) or (tam > max)):
    s1 = input(pergunta)
    tam = len(s1)
  return s1

#Programa principal
x = valida_string('Digite uma string: ', 10, 30)
print('Você digitou a string: {}. \n Dado válido. Encerrando o programa...'.format(x))

# %% [markdown]
# **Erros**

# %% [markdown]
# Exceção - ValueError

# %%
while True:
  try:
    x=int(input('Por favor digite um número: '))
    break
  except ValueError:
    print('Oops! Número inválido. Tente novamente...')

# %% [markdown]
# Exceção - IndexError

# %%
i = 0
while True:
  try:
    nome = input('Por favor digite o seu nome: ')
    ind = int(input('Digite um indice do seu nome digitado: '))
    print(nome[ind])
    break
  except ValueError:
    print('Oops! Nome inválido. Tente novamente...')
  except IndexError:
    print('Oops! índice inválido. Tente novamente...')
  finally:
    print(f'Tentativa {i}')
    i += 1

# %% [markdown]
# Exceção - ZeroDivisionError

# %%
def div():
  try:
    num1 = int(input("Digite um número: "))
    num2 = int(input("Digite um número: "))
    res = num1 / num2
  except ZeroDivisionError:
    print("Oops! Erro de divisão por zero...")
  except:
    print("Algo de errado aconteceu...")
  else:
    return res
  finally:
    print("Executará sempre!")

  # programa principal
  print(div())

# %% [markdown]
# **Função lambda**

# %%
res = lambda x: x * x
print(res (3))

soma = lambda x, y: x + y
print(soma (3,5))

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1. Faça uma função lambda que recebe dois valores numéricos como parâmetro. Ao primeiro valor, sempre some 5. Em seguida, multiplique ambos e retorne o resultado

# %%
calc = lambda a, b: (a + 5) * b
print(calc(5, 10))

# %% [markdown]
# **Tuplas**

# %%
mochila = ('Machado', 'Camisa', 'Bacon', 'Abacate')

print(mochila)
print(mochila[0])    # print do Elemento 1 Indice 0
print(mochila [2])   # print do Elemento 3 Índice 2
print(mochila [0:2]) # print dos Elementos 1 e 2 Índice 0 e 1
print(mochila [2:])  # print dos elementos a partir do índice 2
print(mochila [-1])  # print do último
# Out:
# ('Machado', 'Camisa', 'Bacon', 'Abacate')
# Machado
# Bacon
# ('Machado', 'Camisa')
# ('Bacon', 'Abacate')
# Abacate

# %%
for item in mochila:
  print(f'Na minha mochila tem: (item)')

tam = len(mochila)
for i in range (0, tam, 1):
  print(f'Na minha mochila tem: (mochila[i])')
# Out:
# Na minha mochila tem: (item)
# Na minha mochila tem: (item)
# Na minha mochila tem: (item)
# Na minha mochila tem: (item)
# Na minha mochila tem: (mochila[i])
# Na minha mochila tem: (mochila[i])
# Na minha mochila tem: (mochila[i])
# Na minha mochila tem: (mochila[i])

# %%
mochila[2] = 'Ovos' # vai dar erro

# %%
mochila = ('Machado', 'Camisa', 'Bacon', 'Abacate')
upgrade = ('Queijo', 'Canivete')

mochila_grande = mochila + upgrade

print(mochila)
print(upgrade)
print(mochila_grande)

# %%
mochila_grande_invertida = upgrade + mochila

print(mochila_grande)
print(mochila_grande_invertida)

# %% [markdown]
# Desempacotamento de parâmetros em funções

# %%
def soma(*num):
  acumulador = 0
  print(f'Tupla: (num)')
  for i in num:
    acumulador += i
  return acumulador

#Programa principal
print(f'Resultado: {soma(1,2)}\n')
print(f'Resultado: {soma(1,2,3,4,5,6,7,8,9)}\n')
# Out:
# Tupla: (num)
# Resultado: 3
#
# Tupla: (num)
# Resultado: 45

# %% [markdown]
# **Listas**

# %%
mochila = ('Machado', 'Camisa', 'Bacon', 'Abacate')
print('Tupla:', mochila)

mochila = ['Machado', 'Camisa', 'Bacon', 'Abacate']
print('Lista:', mochila)
# Out:
# Tupla: ('Machado', 'Camisa', 'Bacon', 'Abacate')
# Lista: ['Machado', 'Camisa', 'Bacon', 'Abacate']

# %%
mochila[2] = 'Laranja'
print('Lista:', mochila)
# Out:
# Lista: ['Machado', 'Camisa', 'Laranja', 'Abacate']

# %% [markdown]
# **Manipulação de listas**

# %% [markdown]
# Inserir dados

# %%
mochila.append('Ovos')          # adiciona no final da lista
print('Lista:', mochila)

mochila.insert(1, 'Canivete')   # insere na posição informada
print('Lista:', mochila)
# Out:
# Lista: ['Machado', 'Camisa', 'Laranja', 'Abacate', 'Ovos']
# Lista: ['Machado', 'Canivete', 'Camisa', 'Laranja', 'Abacate', 'Ovos']
# Lista: ['Machado', 'Camisa', 'Laranja', 'Abacate', 'Ovos']
# Lista: ['Machado', 'Camisa', 'Laranja', 'Abacate']

# %% [markdown]
# Deletar dados

# %%
del mochila [1]                 # deleta do indice informado
print('Lista:', mochila)

mochila.remove('Ovos')          # deleta o dado informado
print('Lista:', mochila)

# %% [markdown]
# Copiar listas

# %%
# mesma referência
lista_original = [5, 7, 9, 11]
lista_referenciada = lista_original

print(lista_original)
print(lista_referenciada)

# %%
# aqui ambas as listas serão alteradas
lista_referenciada [0] = 2
print(lista_original)
print(lista_referenciada)

# %%
#cópia
lista_original [5, 7, 9, 11]
lista_referenciada = lista_original[:]

print(lista_original)
print(lista_referenciada)

lista_referenciada [0] = 2
print(lista_original)
print(lista_referenciada)

# %% [markdown]
# **Strings e listas dentro de listas**

# %%
mochila = ['Machado', 'Camisa', 'Bacon', 'Abacate']
print(mochila[0])

mochila = ['Machado', 'Camisa', 'Bacon', 'Abacate']
print(mochila[0][0])
print(mochila[2][1])
# Out:
# Machado
# M
# a

# %%
mochila = ['Machado', 'Camisa', 'Bacon', 'Abacate']
for item in mochila:
  for letra in item:
    print(letra, end='')
  print()
# Out:
# Machado
# Camisa
# Bacon
# Abacate

# %%
# uma palavra por linha
mochila = ['Machado', 'Camisa', 'Bacon', 'Abacate']
for i in range(0,len (mochila), 1):
  for j in range(0,len(mochila[i]),1):
    print(mochila[i][j], end='')
  print()
# Out:
# Machado
# Camisa
# Bacon
# Abacate

# %% [markdown]
# **Exercício**

# %% [markdown]
# 1. Imagine uma situação na qual você deve realizar o cadastro de uma lista de compras em um sistema. Cada produto comprado deverá ser registrado com seu nome, quantidade e valor unitário

# %%
item = []
mercado = []
for i in range(3):
  item.append(input('Digite o nome do item:'))
  item.append(int(input('Digite a quantidade:')))
  item.append(float(input('Digite o valor:')))
  mercado.append(item[:])
  item.clear()
print(mercado)
# Out:
# Digite o nome do item:morango
# Digite a quantidade:2
# Digite o valor:2.00
# Digite o nome do item:tomate
# Digite a quantidade:1
# Digite o valor:1.00
# Digite o nome do item:cebola
# Digite a quantidade:1
# Digite o valor:100.00
# [['morango', 2, 2.0], ['tomate', 1, 1.0], ['cebola', 1, 100.0]]

# %%
mercado = []
for i in range(3):
  nome = input('Digite o nome do item:')
  qtd = int(input('Digite a quantidade:'))
  valor = float(input('Digite o valor:'))
  mercado.append([nome, qtd, valor])
print(mercado)
# Out:
# Digite o nome do item:morango
# Digite a quantidade:1
# Digite o valor:1.00
# Digite o nome do item:tomate
# Digite a quantidade:2
# Digite o valor:2.00
# Digite o nome do item:cebola
# Digite a quantidade:3
# Digite o valor:3.00
# [['morango', 1, 1.0], ['tomate', 2, 2.0], ['cebola', 3, 3.0]]

# %%
soma = 0
print('Lista de compras:')
print( '-' * 20)
print('item | quantidade | valor unitário | total do item')

for item in mercado:
  print('{} | {} | {} | {}'.format(item[0], item[1], item[2], item [1] * item[2]))
  soma += item[1]* item[2]

print('-' * 20)
print(f'Total a ser pago: {soma}')
# Out:
# Lista de compras:
# --------------------
# item | quantidade | valor unitário | total do item
# morango | 1 | 1.0 | 1.0
# tomate | 2 | 2.0 | 4.0
# cebola | 3 | 3.0 | 9.0
# --------------------
# Total a ser pago: 14.0

# %% [markdown]
# **Dicionários**

# %%
mochila = ('Laptop', 'Smartphone', 'Power Bank', 'Carregadores e Cabos')
print('Tupla: ', mochila)

mochila = ['Laptop', 'Smartphone', 'Power Bank', 'Carregadores e Cabos']
print('Lista: ', mochila)

mochila = {'Laptop': 1, 'Smartphone': 2, 'Power Bank': 3, 'Carregadores e Cabos':4}
print('Dicionário: ', mochila)
# Out:
# Tupla:  ('Laptop', 'Smartphone', 'Power Bank', 'Carregadores e Cabos')
# Lista:  ['Laptop', 'Smartphone', 'Power Bank', 'Carregadores e Cabos']
# Dicionário:  {'Laptop': 1, 'Smartphone': 2, 'Power Bank': 3, 'Carregadores e Cabos': 4}

# %%
game = {'nome': 'Super Mario',
        'desenvolvedora': 'Nintendo',
        'ano': 1990}

print(nome)
print()
print(game['nome'])
print(game['desenvolvedora'])
print(game['ano'])
# Out:
# cebola
#
# Super Mario
# Nintendo
# 1990

# %% [markdown]
# **Métodos para dicionários**

# %% [markdown]
# Values

# %%
print(game.values())
# Out:
# dict_values(['Super Mario', 'Nintendo', 1990])

# %% [markdown]
# Keys

# %%
print(game.keys())
# Out:
# dict_keys(['nome', 'desenvolvedora', 'ano'])

# %% [markdown]
# Items

# %%
print(game.items())
# Out:
# dict_items([('nome', 'Super Mario'), ('desenvolvedora', 'Nintendo'), ('ano', 1990)])

# %%
for values in game.values():
  print(values)
  print(game.keys())
# Out:
# Super Mario
# dict_keys(['nome', 'desenvolvedora', 'ano'])
# Nintendo
# dict_keys(['nome', 'desenvolvedora', 'ano'])
# 1990
# dict_keys(['nome', 'desenvolvedora', 'ano'])

# %%
for keys in game.keys():
  print(keys)
  print(game.items())
# Out:
# nome
# dict_items([('nome', 'Super Mario'), ('desenvolvedora', 'Nintendo'), ('ano', 1990)])
# desenvolvedora
# dict_items([('nome', 'Super Mario'), ('desenvolvedora', 'Nintendo'), ('ano', 1990)])
# ano
# dict_items([('nome', 'Super Mario'), ('desenvolvedora', 'Nintendo'), ('ano', 1990)])

# %%
for keys, values in game.items():
  print(f'{keys} = {values}')
# Out:
# nome = Super Mario
# desenvolvedora = Nintendo
# ano = 1990

# %% [markdown]
# Lista com dicionários

# %%
games = []
game1 = {'nome': 'Super Mario', 'videogame': 'Super Nintendo', 'ano': 1990}
game2 = {'nome': 'Zelda Ocarina of Time', 'videogame': 'Nintendo 64', 'ano': 1998}
game3 = {'nome': 'Pokemon Yellow', 'videogame': 'Game Boy', 'ano':1999}
games = [game1, game2, game3]

print(games)
# Out:
# [{'nome': 'Super Mario', 'videogame': 'Super Nintendo', 'ano': 1990}, {'nome': 'Zelda Ocarina of Time', 'videogame': 'Nintendo 64', 'ano': 1998}, {'nome': 'Pokemon Yellow', 'videogame': 'Game Boy', 'ano': 1999}]

# %%
game = {}
games = []

for i in range(3):
  game['nome'] = input('Qual o nome do jogo?')
  game ['videogame'] = input('Para qual video-game ele foi lançado?')
  game['ano'] = input('Qual o ano de lançamento?')
  games.append(game.copy())

print('-' * 20)

for jogos in games:
  for chave, valor in jogos.items():
    print(f'o campo {chave} tem o valor {valor.')
# Out:
# Qual o nome do jogo?fdsg
# Para qual video-game ele foi lançado?2000
# Qual o ano de lançamento?200
# Qual o nome do jogo?tttt
# Para qual video-game ele foi lançado?0200
# Qual o ano de lançamento?2000
# Qual o nome do jogo?ohkdofh
# Para qual video-game ele foi lançado?34234
# Qual o ano de lançamento?42233
# --------------------
# o campo nome tem o valor fdsg.
# o campo videogame tem o valor 2000.
# o campo ano tem o valor 200.
# o campo nome tem o valor tttt.
# o campo videogame tem o valor 0200.
# o campo ano tem o valor 2000.
# o campo nome tem o valor ohkdofh.
# o campo videogame tem o valor 34234.
# o campo ano tem o valor 42233.

# %% [markdown]
# Dicionários com listas

# %%
games = {'nome': ['Super Mario', 'Zelda Ocarina of Time', 'Pokemon Yellow'],
         'videogame': ['Super Nintendo', 'Nintendo 64', 'Game Boy'],
         'ano': [1990, 19998,1999]}

print(games)
# Out:
# {'nome': ['Super Mario', 'Zelda Ocarina of Time', 'Pokemon Yellow'], 'videogame': ['Super Nintendo', 'Nintendo 64', 'Game Boy'], 'ano': [1990, 19998, 1999]}

# %%
games = {'nome': [], 'videogame': [], 'ano': []}

for i in range(3):
  nome = input('Qual o nome do jogo?')
  videogame = input('Para qual video-game ele foi lançado?')
  ano = input('Qual o ano de lançamento?')
  games['nome'].append(nome)
  games['videogame'].append(videogame)
  games['ano'].append(ano)

print('-' * 20)
print(games)
# Out:
# Qual o nome do jogo?jgdhk
# Para qual video-game ele foi lançado?6768
# Qual o ano de lançamento?ghjk
# Qual o nome do jogo?5675
# Para qual video-game ele foi lançado?hgj
# Qual o ano de lançamento?567
# Qual o nome do jogo?hgjc
# Para qual video-game ele foi lançado?757
# Qual o ano de lançamento?7565
# --------------------
# {'nome': ['jgdhk', '5675', 'hgjc'], 'videogame': ['6768', 'hgj', '757'], 'ano': ['ghjk', '567', '7565']}

# %% [markdown]
# **Métodos em strings**

# %%
# vai dar erro

s1 = 'Algoritmos'
print(s1)
s1[0] = 'a'

# %%
s1 = list('Algoritmos')

print(s1) # print separado
print(''.join(s1)) # print agrupado
# Out:
# ['A', 'l', 'g', 'o', 'r', 'i', 't', 'm', 'o', 's']
# Algoritmos

# %%
s1[0] = 'a'
print(''.join(s1))
# Out:
# algoritmos

# %% [markdown]
# Verificando caracteres

# %% [markdown]
# Começa

# %%
s1= 'Lógica de Programação e Algoritmos'
s1.startswith('Lógica')

# %% [markdown]
# Termina

# %%
s1 = 'Lógica de Programação e Algoritmos'
s1.endswith('Algoritmos')

s1 = 'Lógica de Programação e Algoritmos'
s1.endswith('algoritmos')

s1 = 'Lógica de Programação e Algoritmos'
s1.lower().endswith('algoritmos')

# %%
s1 -= 'Lógica de Programação e Algoritmos'

print(s1.upper()) # maiusculas
print(s1.lower()) # minusculas

# %% [markdown]
# Contando strings

# %%
s1 = 'Lógica de Programação e Algoritmas'
s1.count('a')

s1 = 'Lógica de Programação e Algoritmos'
s1.lower().count('a')

s1 = 'Um mafagafinho, dois mafagafinhos, três mafagafinhos...'
s1.lower().count('mafagafinho')

# %% [markdown]
# Quebrando strings

# %%
s1 = 'Um mafagafinho, dois mafagafinhos, três mafagafinhos....'
s1.split('')

# %% [markdown]
# Substituindo strings

# %%
s1 = 'Um mafagafinho, dois mafagafinhos, très mafagafinhos...'
s1.replace('mafagafinho', 'gatinha')

s1= 'Um mafagafinho, dois mafagafinhos, três mafagafinhos....'
s1.replace('mafagafinho', 'gatinho', 1)

# %% [markdown]
# **Validando tipos de dados**

# %%
s1='Lógica de Programação e Algoritmos!'
s2 = '42'

print(s1.isalnum()) # apenas letas numeros e acentos - espaço não entra
print(s2.isalnum())

print(s1.isalpha()) # apenas letas
print(s2.isalpha())

s1 = 'Lógicade ProgramaçãoeAlgoritmos'
print(s1.isalpha()) # apenas letas numeros e acentos - True porque não tem espaços
